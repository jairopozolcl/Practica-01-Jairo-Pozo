# %% [markdown]
# <a href="https://colab.research.google.com/github/jairopozolcl/Practica-01-Jairo-Pozo/blob/main/pr_ctica_01_jairo_pozo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola, ¿cómo te llamas?")
nombre = input()
print ("¿Te llamas " + nombre + "?")
print ("¿Qué edad tienes?")
edad = input()
print ("Así que tu edad es " + edad + ", ¿verdad?")
# Out:
# Hola, ¿cómo te llamas?
# Jairo
# ¿Te llamas Jairo?
# ¿Qué edad tienes?
# 27
# Así que tu edad es 27, ¿verdad?

# %%
base=9
altura=90
area = base * altura
print("El área es: "+ str(area))
# Out:
# El área es: 810

# %%
texto = "tres"
texto2 = "tres tristes tigres comen trigo en un trigal tres veces ¿tres, tres, tres?"
texto2.count (texto)
# Out:
# 5

# %%
letra = input("Escribe una letra minúscula:")
mayúscula = letra.upper()
print ("La letra mayúscula es:", mayúscula)
# Out:
# Escribe una letra minúscula:e
# La letra mayúscula es: E
